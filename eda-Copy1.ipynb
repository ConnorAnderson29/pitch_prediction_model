# %% [markdown]
# # Exploratory Data Analysis/Data Preparation/Data Exportation
#
# #### The purpose of this notebook is to collect and clean data, perform preliminary eda and output dataframes as CSV for later combination in another notebook

# %% [markdown]
# #### Importing the necessary libraries

# %%
#DATA WRANGLING
import pandas as pd # Dataframes
from pandas.io.json import json_normalize # JSON wrangler
import statsapi # Python wrapper MLB data API

# %%
#DATA STORAGE
#from sqlalchemy import create_engine # SQL helper
import psycopg2 as psql #PostgreSQL DBs

# %%
#DATA MANIPULATION AND MODELLING
import numpy as np
np.random.seed(0)
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn_pandas import DataFrameMapper, FunctionTransformer, gen_features, pipeline
from sklearn_pandas.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import seaborn as sns
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score
from sklearn.preprocessing import LabelBinarizer
import xgboost as xgb
import os
import pitch_functions
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-2f1efbba499f> in <module>
#      16 import xgboost as xgb
#      17 import os
# ---> 18 import pitch_functions
#
# ~/flatiron/projects /capstone/pitch_prediction_model/pitch_functions.py in <module>
#      25
#      26 # Neural Networks
# ---> 27 from keras.models import Sequential
#      28 from keras.layers import Dense, LSTM
#      29 from keras.utils import to_categorical
#
# /Applications/anaconda3/lib/python3.7/site-packages/keras/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# /Applications/anaconda3/lib/python3.7/site-packages/keras/utils/__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# /Applications/anaconda3/lib/python3.7/site-packages/keras/utils/conv_utils.py in <module>
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# /Applications/anaconda3/lib/python3.7/site-packages/keras/backend/__init__.py in <module>
#      87 elif _BACKEND == 'tensorflow':
#      88     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 89     from .tensorflow_backend import *
#      90 else:
#      91     # Try and load external backend.
#
# /Applications/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.framework import ops as tf_ops
#       7 from tensorflow.python.training import moving_averages
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ## Data Extraction
# Calling the StatsApi ```https://pypi.org/project/MLB-StatsAPI/``` to collect infomation about all MLB games played between 03/28/18 and 10/03/18. The schulde function will be used in order to collect specific game identifiers, those game identifiers will be used inside of a For Loop that will extract play-by-play data from each game and create a brand new data frame with game data.

# %% [markdown]
# Importing team codes from TSV file in ```public_data direcrtory```. Using this data to construct a data frame of each teams identifier for use later.

# %%
teams = pd.read_csv('public_data/team_codes.tsv', sep='\t')

teams['full_name'] = teams['full_name'].str.lower().str.replace(' ', '_').str.replace('-','_')

# %%
teams.head()
# Out:
#    code short_name full_name
# 0   108        LAA    angels
# 1   109        ARI   d_backs
# 2   110        BAL   orioles
# 3   111        BOS   red_sox
# 4   112        CHC      cubs

# %%
team_code = []
for code, team_name in zip(teams['code'],teams['full_name']):
    text = (f'The {team_name} has code {code}')
    team_code.append(text)
team_code_df = pd.DataFrame(team_code)
team_code_df.head(1)
# Out:
#                          0
# 0  The angels has code 108

# %%
schedule = statsapi.schedule(start_date="07/03/2019", end_date="07/03/2019")

# %%
full = json_normalize(schedule)
gamepks= full['game_id']

# %%
full.head(2)
# Out:
#    away_id       away_name                                  away_pitcher_note  \
# 0      116  Detroit Tigers  Norris had the makings of a quality start last...
# 1      116  Detroit Tigers  Tyler Alexander will make his Major League deb...
#
#   away_probable_pitcher away_score current_inning doubleheader   game_date  \
# 0        Norris, Daniel          3              5            S  2019-07-03
# 1      Alexander, Tyler          0                           S  2019-07-03
#
#           game_datetime  game_id  game_num game_type  home_id  \
# 0  2019-07-03T18:10:00Z   567273         1         R      145
# 1  2019-07-04T00:10:00Z   567305         2         R      145
#
#            home_name                                  home_pitcher_note  \
# 0  Chicago White Sox  The long-awaited Major League debut of MLB Pip...
# 1  Chicago White Sox  The veteran left-hander picked up his first vi...
#
#   home_probable_pitcher home_score inning_state       status  \
# 0          Cease, Dylan          4       Bottom  In Progress
# 1        Detwiler, Ross          0                 Scheduled
#
#                                              summary
# 0  2019-07-03 - Detroit Tigers (3) @ Chicago Whit...
# 1  2019-07-03 - Detroit Tigers @ Chicago White So...

# %%
gamepks_2018 = list(gamepks.unique())
len(gamepks_2018)
# Out:
# 16

# %%
test_pk = gamepks_2018

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data Frame Creation
#
# This loop iterates through the game_pks from the above list, grabs the game data assoicated with each game pk and breaks it out into a custom human usuable pandas dataframe. The column names are defined manually so that only necessary columns are added to the data frame.
# In the second loop, it iterates through play events in the current plays dataframe, this normalizes the ```.json``` nested in this data frame in the play events column. A dictionary is then defined, and several columns are added to the dictionary. This columns are used to add the prior pitch to the data frame. The prior pitch is important when determining patterns in pitcher tendencies. If/Else statements are then used to add each column and row to the dictionary which is then appended to a list, which is used to create a final dataframe.

# %%
list_for_final_df = []
for game in test_pk:
    curr_game = statsapi.get('game_playByPlay',{'gamePk':game})
    curr_plays = curr_game.get('allPlays')
    curr_plays_df = pd.DataFrame(curr_plays)
    curr_plays_norm = json_normalize(curr_plays)
    
    all_plays_cols = ['about.atBatIndex', 'about.halfInning', 'about.inning', 'count.balls', 'count.strikes', 'matchup.batSide.code', 
                     'matchup.batter.fullName', 'matchup.batter.id', 'matchup.pitchHand.code', 'matchup.splits.menOnBase', 'matchup.pitcher.fullName',
                     'matchup.pitcher.id', 'result.eventType']
    
    play_events_cols = ['count.balls', 'count.strikes', 'details.ballColor', 'details.call.code', 'details.call.description', 'details.type.description'
                        ,'details.call.code', 'details.description', 'details.code', 'details.type.code', 'index', 'pitchData.nastyFactor',
                       'pitchData.zone', 'pitchNumber', 'type']
    i = 1
    for index, row in curr_plays_norm.iterrows():
            play_events = json_normalize(row['playEvents'])
            
            for play_events_idx, play_events_row in play_events.iterrows():
                
                game_dict = {}
                game_dict['gamepk'] = game
                game_dict['pitch_id']  = str(game) + '_' + str(row['about.atBatIndex']) + '_' + str(i)
                game_dict['prior_pitch'] = str(game) + '_' + (str(row['about.atBatIndex']) + '_' + str(i - 1))
                
                
                for col_all_plays in all_plays_cols:
                    if col_all_plays in curr_plays_norm.columns:
                        game_dict[col_all_plays] = row[col_all_plays]
                    else:
                        game_dict[col_all_plays] = np.nan
                for col_play_events in play_events_cols:
                    if col_play_events in play_events.columns:
                        game_dict[col_play_events] = play_events_row[col_play_events]
                    else: 
                        game_dict[col_play_events] = np.nan
                
                list_for_final_df.append(game_dict)
                i += 1

# %%
each_pitch = pd.DataFrame(list_for_final_df)
each_pitch
# Out:
#      about.atBatIndex about.halfInning  about.inning  count.balls  \
# 0                   0              top             1          0.0
# 1                   1              top             1          1.0
# 2                   1              top             1          2.0
# 3                   1              top             1          2.0
# 4                   1              top             1          2.0
# 5                   1              top             1          2.0
# 6                   2              top             1          0.0
# 7                   2              top             1          1.0
# 8                   2              top             1          1.0
# 9                   2              top             1          1.0
# 10                  2              top             1          2.0
# 11                  2              top             1          3.0
# 12                  2              top             1          3.0
# 13                  2              top             1          4.0
# 14                  3              top             1          0.0
# 15                  3              top             1          1.0
# 16                  3              top             1          2.0
# 17                  3              top             1          NaN
# 18                  3              top             1          3.0
# 19                  3              top             1          4.0
# 20                  4              top             1          0.0
# 21                  4              top             1          0.0
# 22                  4              top             1          1.0
# 23                  4              top             1          1.0
# 24                  4              top             1          2.0
# 25                  5              top             1          0.0
# 26                  5              top             1          0.0
# 27                  5              top             1          0.0
# 28                  6              top             1          1.0
# 29                  6              top             1          1.0
# ..                ...              ...           ...          ...
# 170                38           bottom             4          1.0
# 171                39              top             5          1.0
# 172                39              top             5          1.0
# 173                39              top             5          1.0
# 174                39              top             5          1.0
# 175                39              top             5          1.0
# 176                40              top             5          0.0
# 177                40              top             5          0.0
# 178                40              top             5          0.0
# 179                41              top             5          0.0
# 180                42              top             5          0.0
# 181                42              top             5          0.0
# 182                42              top             5          1.0
# 183                42              top             5          2.0
# 184                42              top             5          2.0
# 185                43           bottom             5          0.0
# 186                43           bottom             5          0.0
# 187                43           bottom             5          1.0
# 188                43           bottom             5          2.0
# 189                43           bottom             5          2.0
# 190                43           bottom             5          2.0
# 191                43           bottom             5          2.0
# 192                44           bottom             5          0.0
# 193                44           bottom             5          1.0
# 194                44           bottom             5          1.0
# 195                44           bottom             5          1.0
# 196                45           bottom             5          1.0
# 197                45           bottom             5          1.0
# 198                45           bottom             5          1.0
# 199                45           bottom             5          1.0
#
#      count.strikes       details.ballColor details.call.code  \
# 0              0.0  rgba(26, 86, 190, 1.0)                 X
# 1              0.0  rgba(39, 161, 39, 1.0)                 B
# 2              0.0  rgba(39, 161, 39, 1.0)                 B
# 3              1.0  rgba(170, 21, 11, 1.0)                 S
# 4              2.0  rgba(170, 21, 11, 1.0)                 S
# 5              2.0  rgba(26, 86, 190, 1.0)                 X
# 6              1.0  rgba(170, 21, 11, 1.0)                 S
# 7              1.0  rgba(39, 161, 39, 1.0)                 B
# 8              1.0                     NaN               NaN
# 9              2.0  rgba(170, 21, 11, 1.0)                 S
# 10             2.0  rgba(39, 161, 39, 1.0)                 B
# 11             2.0  rgba(39, 161, 39, 1.0)                 B
# 12             2.0  rgba(170, 21, 11, 1.0)                 S
# 13             2.0  rgba(39, 161, 39, 1.0)                 B
# 14             1.0  rgba(170, 21, 11, 1.0)                 S
# 15             1.0  rgba(39, 161, 39, 1.0)                 B
# 16             1.0  rgba(39, 161, 39, 1.0)                 B
# 17             NaN                     NaN               NaN
# 18             1.0  rgba(39, 161, 39, 1.0)                 B
# 19             1.0  rgba(39, 161, 39, 1.0)                 B
# 20             1.0  rgba(170, 21, 11, 1.0)                 S
# 21             2.0  rgba(170, 21, 11, 1.0)                 S
# 22             2.0  rgba(39, 161, 39, 1.0)                 B
# 23             2.0  rgba(170, 21, 11, 1.0)                 S
# 24             2.0  rgba(39, 161, 39, 1.0)                 B
# 25             0.0                     NaN               NaN
# 26             1.0  rgba(170, 21, 11, 1.0)                 S
# 27             1.0  rgba(26, 86, 190, 1.0)                 X
# 28             0.0  rgba(39, 161, 39, 1.0)                 B
# 29             1.0  rgba(170, 21, 11, 1.0)                 S
# ..             ...                     ...               ...
# 170            1.0  rgba(26, 86, 190, 1.0)                 X
# 171            0.0  rgba(39, 161, 39, 1.0)                 B
# 172            1.0  rgba(170, 21, 11, 1.0)                 S
# 173            2.0  rgba(170, 21, 11, 1.0)                 S
# 174            2.0  rgba(170, 21, 11, 1.0)                 S
# 175            2.0  rgba(26, 86, 190, 1.0)                 X
# 176            1.0  rgba(170, 21, 11, 1.0)                 S
# 177            2.0  rgba(170, 21, 11, 1.0)                 S
# 178            3.0  rgba(170, 21, 11, 1.0)                 S
# 179            0.0  rgba(26, 86, 190, 1.0)                 X
# 180            1.0  rgba(170, 21, 11, 1.0)                 S
# 181            2.0  rgba(170, 21, 11, 1.0)                 S
# 182            2.0  rgba(39, 161, 39, 1.0)                 B
# 183            2.0  rgba(39, 161, 39, 1.0)                 B
# 184            3.0  rgba(170, 21, 11, 1.0)                 S
# 185            0.0                     NaN               NaN
# 186            0.0                     NaN               NaN
# 187            0.0  rgba(39, 161, 39, 1.0)                 B
# 188            0.0  rgba(39, 161, 39, 1.0)                 B
# 189            1.0  rgba(170, 21, 11, 1.0)                 S
# 190            2.0  rgba(170, 21, 11, 1.0)                 S
# 191            2.0  rgba(26, 86, 190, 1.0)                 X
# 192            0.0                     NaN               NaN
# 193            0.0  rgba(39, 161, 39, 1.0)                 B
# 194            1.0  rgba(170, 21, 11, 1.0)                 S
# 195            1.0  rgba(26, 86, 190, 1.0)                 X
# 196            0.0  rgba(39, 161, 39, 1.0)                 B
# 197            1.0  rgba(170, 21, 11, 1.0)                 S
# 198            2.0  rgba(170, 21, 11, 1.0)                 S
# 199            3.0  rgba(170, 21, 11, 1.0)                 S
#
#     details.call.description details.code  \
# 0     Hit Into Play - Out(s)            X
# 1              Ball - Called            B
# 2              Ball - Called            B
# 3          Strike - Swinging            C
# 4          Strike - Swinging            F
# 5     Hit Into Play - Out(s)            X
# 6          Strike - Swinging            C
# 7              Ball - Called            B
# 8                        NaN          NaN
# 9          Strike - Swinging            F
# 10             Ball - Called            B
# 11             Ball - Called            B
# 12         Strike - Swinging            F
# 13             Ball - Called            B
# 14         Strike - Swinging            C
# 15             Ball - Called            B
# 16             Ball - Called            B
# 17                       NaN            1
# 18             Ball - Called            B
# 19             Ball - Called            B
# 20         Strike - Swinging            C
# 21         Strike - Swinging            C
# 22             Ball - Called            B
# 23         Strike - Swinging            F
# 24             Ball - Called            H
# 25                       NaN          NaN
# 26         Strike - Swinging            C
# 27    Hit Into Play - Out(s)            E
# 28             Ball - Called            B
# 29         Strike - Swinging            C
# ..                       ...          ...
# 170   Hit Into Play - Out(s)            X
# 171            Ball - Called            B
# 172        Strike - Swinging            S
# 173        Strike - Swinging            F
# 174        Strike - Swinging            F
# 175   Hit Into Play - Out(s)            X
# 176        Strike - Swinging            S
# 177        Strike - Swinging            F
# 178        Strike - Swinging            C
# 179   Hit Into Play - Out(s)            E
# 180        Strike - Swinging            C
# 181        Strike - Swinging            F
# 182            Ball - Called            B
# 183            Ball - Called            B
# 184        Strike - Swinging            S
# 185                      NaN          NaN
# 186                      NaN          NaN
# 187            Ball - Called            B
# 188            Ball - Called            B
# 189        Strike - Swinging            S
# 190        Strike - Swinging            S
# 191   Hit Into Play - Out(s)            X
# 192                      NaN          NaN
# 193            Ball - Called            B
# 194        Strike - Swinging            F
# 195   Hit Into Play - Out(s)            X
# 196            Ball - Called            B
# 197        Strike - Swinging            C
# 198        Strike - Swinging            F
# 199        Strike - Swinging            S
#
#                                    details.description details.type.code  \
# 0                                      In play, out(s)                FF
# 1                                                 Ball                FF
# 2                                                 Ball                FF
# 3                                        Called Strike                FF
# 4                                                 Foul                FF
# 5                                      In play, out(s)                FF
# 6                                        Called Strike                SL
# 7                                                 Ball                FF
# 8                                      On-field Delay.               NaN
# 9                                                 Foul                FF
# 10                                                Ball                FF
# 11                                                Ball                SL
# 12                                                Foul                SL
# 13                                                Ball                FF
# 14                                       Called Strike                FF
# 15                                                Ball                FF
# 16                                                Ball                FF
# 17                                  Pickoff Attempt 1B               NaN
# 18                                                Ball                FF
# 19                                                Ball                FF
# 20                                       Called Strike                SL
# 21                                       Called Strike                SL
# 22                                                Ball                FF
# 23                                                Foul                SL
# 24                                        Hit By Pitch                FF
# 25                                       Injury Delay.               NaN
# 26                                       Called Strike                SL
# 27                                     In play, run(s)                SL
# 28                                                Ball                FF
# 29                                       Called Strike                SL
# ..                                                 ...               ...
# 170                                    In play, out(s)                FF
# 171                                               Ball                FF
# 172                                    Swinging Strike                CH
# 173                                               Foul                FF
# 174                                               Foul                SL
# 175                                    In play, out(s)                FF
# 176                                    Swinging Strike                CH
# 177                                               Foul                FF
# 178                                      Called Strike                SL
# 179                                    In play, run(s)                CH
# 180                                      Called Strike                FF
# 181                                               Foul                CU
# 182                                               Ball                CH
# 183                                               Ball                FF
# 184                                    Swinging Strike                SL
# 185  Defensive Substitution: Gordon Beckham replace...               NaN
# 186  Defensive switch from second base to center fi...               NaN
# 187                                               Ball                CU
# 188                                               Ball                FT
# 189                                    Swinging Strike                CH
# 190                                    Swinging Strike                CH
# 191                                    In play, out(s)                CH
# 192  Tigers center fielder JaCoby Jones left the ga...               NaN
# 193                                               Ball                SL
# 194                                               Foul                SL
# 195                                    In play, out(s)                FF
# 196                                               Ball                CU
# 197                                      Called Strike                FF
# 198                                               Foul                CH
# 199                                    Swinging Strike                FF
#
#     details.type.description  gamepk  index matchup.batSide.code  \
# 0         Four-Seam Fastball  567273      0                    R
# 1         Four-Seam Fastball  567273      0                    L
# 2         Four-Seam Fastball  567273      1                    L
# 3         Four-Seam Fastball  567273      2                    L
# 4         Four-Seam Fastball  567273      3                    L
# 5         Four-Seam Fastball  567273      4                    L
# 6                     Slider  567273      0                    R
# 7         Four-Seam Fastball  567273      1                    R
# 8                        NaN  567273      2                    R
# 9         Four-Seam Fastball  567273      3                    R
# 10        Four-Seam Fastball  567273      4                    R
# 11                    Slider  567273      5                    R
# 12                    Slider  567273      6                    R
# 13        Four-Seam Fastball  567273      7                    R
# 14        Four-Seam Fastball  567273      0                    R
# 15        Four-Seam Fastball  567273      1                    R
# 16        Four-Seam Fastball  567273      2                    R
# 17                       NaN  567273      3                    R
# 18        Four-Seam Fastball  567273      4                    R
# 19        Four-Seam Fastball  567273      5                    R
# 20                    Slider  567273      0                    L
# 21                    Slider  567273      1                    L
# 22        Four-Seam Fastball  567273      2                    L
# 23                    Slider  567273      3                    L
# 24        Four-Seam Fastball  567273      4                    L
# 25                       NaN  567273      0                    L
# 26                    Slider  567273      1                    L
# 27                    Slider  567273      2                    L
# 28        Four-Seam Fastball  567273      0                    L
# 29                    Slider  567273      1                    L
# ..                       ...     ...    ...                  ...
# 170       Four-Seam Fastball  567273      2                    R
# 171       Four-Seam Fastball  567273      0                    R
# 172                 Changeup  567273      1                    R
# 173       Four-Seam Fastball  567273      2                    R
# 174                   Slider  567273      3                    R
# 175       Four-Seam Fastball  567273      4                    R
# 176                 Changeup  567273      0                    R
# 177       Four-Seam Fastball  567273      1                    R
# 178                   Slider  567273      2                    R
# 179                 Changeup  567273      0                    L
# 180       Four-Seam Fastball  567273      0                    L
# 181                Curveball  567273      1                    L
# 182                 Changeup  567273      2                    L
# 183       Four-Seam Fastball  567273      3                    L
# 184                   Slider  567273      4                    L
# 185                      NaN  567273      0                    R
# 186                      NaN  567273      1                    R
# 187                Curveball  567273      2                    R
# 188        Two-Seam Fastball  567273      3                    R
# 189                 Changeup  567273      4                    R
# 190                 Changeup  567273      5                    R
# 191                 Changeup  567273      6                    R
# 192                      NaN  567273      0                    R
# 193                   Slider  567273      1                    R
# 194                   Slider  567273      2                    R
# 195       Four-Seam Fastball  567273      3                    R
# 196                Curveball  567273      0                    R
# 197       Four-Seam Fastball  567273      1                    R
# 198                 Changeup  567273      2                    R
# 199       Four-Seam Fastball  567273      3                    R
#
#     matchup.batter.fullName  matchup.batter.id matchup.pitchHand.code  \
# 0              JaCoby Jones             592444                      R
# 1          Christin Stewart             621514                      R
# 2          Christin Stewart             621514                      R
# 3          Christin Stewart             621514                      R
# 4          Christin Stewart             621514                      R
# 5          Christin Stewart             621514                      R
# 6      Nicholas Castellanos             592206                      R
# 7      Nicholas Castellanos             592206                      R
# 8      Nicholas Castellanos             592206                      R
# 9      Nicholas Castellanos             592206                      R
# 10     Nicholas Castellanos             592206                      R
# 11     Nicholas Castellanos             592206                      R
# 12     Nicholas Castellanos             592206                      R
# 13     Nicholas Castellanos             592206                      R
# 14            Brandon Dixon             641525                      R
# 15            Brandon Dixon             641525                      R
# 16            Brandon Dixon             641525                      R
# 17            Brandon Dixon             641525                      R
# 18            Brandon Dixon             641525                      R
# 19            Brandon Dixon             641525                      R
# 20        Jeimer Candelario             600869                      R
# 21        Jeimer Candelario             600869                      R
# 22        Jeimer Candelario             600869                      R
# 23        Jeimer Candelario             600869                      R
# 24        Jeimer Candelario             600869                      R
# 25            Harold Castro             605612                      R
# 26            Harold Castro             605612                      R
# 27            Harold Castro             605612                      R
# 28             Niko Goodrum             592348                      R
# 29             Niko Goodrum             592348                      R
# ..                      ...                ...                    ...
# 170            Leury Garcia             544725                      L
# 171    Nicholas Castellanos             592206                      R
# 172    Nicholas Castellanos             592206                      R
# 173    Nicholas Castellanos             592206                      R
# 174    Nicholas Castellanos             592206                      R
# 175    Nicholas Castellanos             592206                      R
# 176           Brandon Dixon             641525                      R
# 177           Brandon Dixon             641525                      R
# 178           Brandon Dixon             641525                      R
# 179       Jeimer Candelario             600869                      R
# 180           Harold Castro             605612                      R
# 181           Harold Castro             605612                      R
# 182           Harold Castro             605612                      R
# 183           Harold Castro             605612                      R
# 184           Harold Castro             605612                      R
# 185            Yoan Moncada             660162                      L
# 186            Yoan Moncada             660162                      L
# 187            Yoan Moncada             660162                      L
# 188            Yoan Moncada             660162                      L
# 189            Yoan Moncada             660162                      L
# 190            Yoan Moncada             660162                      L
# 191            Yoan Moncada             660162                      L
# 192              Jose Abreu             547989                      L
# 193              Jose Abreu             547989                      L
# 194              Jose Abreu             547989                      L
# 195              Jose Abreu             547989                      L
# 196            James McCann             543510                      L
# 197            James McCann             543510                      L
# 198            James McCann             543510                      L
# 199            James McCann             543510                      L
#
#     matchup.pitcher.fullName  matchup.pitcher.id matchup.splits.menOnBase  \
# 0                Dylan Cease              656302                    Empty
# 1                Dylan Cease              656302                    Empty
# 2                Dylan Cease              656302                    Empty
# 3                Dylan Cease              656302                    Empty
# 4                Dylan Cease              656302                    Empty
# 5                Dylan Cease              656302                    Empty
# 6                Dylan Cease              656302                   Men_On
# 7                Dylan Cease              656302                   Men_On
# 8                Dylan Cease              656302                   Men_On
# 9                Dylan Cease              656302                   Men_On
# 10               Dylan Cease              656302                   Men_On
# 11               Dylan Cease              656302                   Men_On
# 12               Dylan Cease              656302                   Men_On
# 13               Dylan Cease              656302                   Men_On
# 14               Dylan Cease              656302                     RISP
# 15               Dylan Cease              656302                     RISP
# 16               Dylan Cease              656302                     RISP
# 17               Dylan Cease              656302                     RISP
# 18               Dylan Cease              656302                     RISP
# 19               Dylan Cease              656302                     RISP
# 20               Dylan Cease              656302                   Loaded
# 21               Dylan Cease              656302                   Loaded
# 22               Dylan Cease              656302                   Loaded
# 23               Dylan Cease              656302                   Loaded
# 24               Dylan Cease              656302                   Loaded
# 25               Dylan Cease              656302                     RISP
# 26               Dylan Cease              656302                     RISP
# 27               Dylan Cease              656302                     RISP
# 28               Dylan Cease              656302                   Loaded
# 29               Dylan Cease              656302                   Loaded
# ..                       ...                 ...                      ...
# 170            Daniel Norris              596057                    Empty
# 171              Dylan Cease              656302                    Empty
# 172              Dylan Cease              656302                    Empty
# 173              Dylan Cease              656302                    Empty
# 174              Dylan Cease              656302                    Empty
# 175              Dylan Cease              656302                    Empty
# 176              Dylan Cease              656302                    Empty
# 177              Dylan Cease              656302                    Empty
# 178              Dylan Cease              656302                    Empty
# 179              Dylan Cease              656302                    Empty
# 180              Dylan Cease              656302                    Empty
# 181              Dylan Cease              656302                    Empty
# 182              Dylan Cease              656302                    Empty
# 183              Dylan Cease              656302                    Empty
# 184              Dylan Cease              656302                    Empty
# 185            Daniel Norris              596057                    Empty
# 186            Daniel Norris              596057                    Empty
# 187            Daniel Norris              596057                    Empty
# 188            Daniel Norris              596057                    Empty
# 189            Daniel Norris              596057                    Empty
# 190            Daniel Norris              596057                    Empty
# 191            Daniel Norris              596057                    Empty
# 192            Daniel Norris              596057                    Empty
# 193            Daniel Norris              596057                    Empty
# 194            Daniel Norris              596057                    Empty
# 195            Daniel Norris              596057                    Empty
# 196            Daniel Norris              596057                    Empty
# 197            Daniel Norris              596057                    Empty
# 198            Daniel Norris              596057                    Empty
# 199            Daniel Norris              596057                    Empty
#
#      pitchData.nastyFactor  pitchData.zone  pitchNumber       pitch_id  \
# 0                      NaN             NaN          1.0     567273_0_1
# 1                      NaN             NaN          1.0     567273_1_2
# 2                      NaN             NaN          2.0     567273_1_3
# 3                      NaN             NaN          3.0     567273_1_4
# 4                      NaN             NaN          4.0     567273_1_5
# 5                      NaN             NaN          5.0     567273_1_6
# 6                      NaN             NaN          1.0     567273_2_7
# 7                      NaN             NaN          2.0     567273_2_8
# 8                      NaN             NaN          NaN     567273_2_9
# 9                      NaN             NaN          3.0    567273_2_10
# 10                     NaN             NaN          4.0    567273_2_11
# 11                     NaN             NaN          5.0    567273_2_12
# 12                     NaN             NaN          6.0    567273_2_13
# 13                     NaN             NaN          7.0    567273_2_14
# 14                     NaN             NaN          1.0    567273_3_15
# 15                     NaN             NaN          2.0    567273_3_16
# 16                     NaN             NaN          3.0    567273_3_17
# 17                     NaN             NaN          NaN    567273_3_18
# 18                     NaN             NaN          4.0    567273_3_19
# 19                     NaN             NaN          5.0    567273_3_20
# 20                     NaN             NaN          1.0    567273_4_21
# 21                     NaN             NaN          2.0    567273_4_22
# 22                     NaN             NaN          3.0    567273_4_23
# 23                     NaN             NaN          4.0    567273_4_24
# 24                     NaN             NaN          5.0    567273_4_25
# 25                     NaN             NaN          NaN    567273_5_26
# 26                     NaN             NaN          1.0    567273_5_27
# 27                     NaN             NaN          2.0    567273_5_28
# 28                     NaN             NaN          1.0    567273_6_29
# 29                     NaN             NaN          2.0    567273_6_30
# ..                     ...             ...          ...            ...
# 170                    NaN             NaN          3.0  567273_38_171
# 171                    NaN             NaN          1.0  567273_39_172
# 172                    NaN             NaN          2.0  567273_39_173
# 173                    NaN             NaN          3.0  567273_39_174
# 174                    NaN             NaN          4.0  567273_39_175
# 175                    NaN             NaN          5.0  567273_39_176
# 176                    NaN             NaN          1.0  567273_40_177
# 177                    NaN             NaN          2.0  567273_40_178
# 178                    NaN             NaN          3.0  567273_40_179
# 179                    NaN             NaN          1.0  567273_41_180
# 180                    NaN             NaN          1.0  567273_42_181
# 181                    NaN             NaN          2.0  567273_42_182
# 182                    NaN             NaN          3.0  567273_42_183
# 183                    NaN             NaN          4.0  567273_42_184
# 184                    NaN             NaN          5.0  567273_42_185
# 185                    NaN             NaN          NaN  567273_43_186
# 186                    NaN             NaN          NaN  567273_43_187
# 187                    NaN             NaN          1.0  567273_43_188
# 188                    NaN             NaN          2.0  567273_43_189
# 189                    NaN             NaN          3.0  567273_43_190
# 190                    NaN             NaN          4.0  567273_43_191
# 191                    NaN             NaN          5.0  567273_43_192
# 192                    NaN             NaN          NaN  567273_44_193
# 193                    NaN             NaN          1.0  567273_44_194
# 194                    NaN             NaN          2.0  567273_44_195
# 195                    NaN             NaN          3.0  567273_44_196
# 196                    NaN             NaN          1.0  567273_45_197
# 197                    NaN             NaN          2.0  567273_45_198
# 198                    NaN             NaN          3.0  567273_45_199
# 199                    NaN             NaN          4.0  567273_45_200
#
#        prior_pitch result.eventType     type
# 0       567273_0_0        field_out    pitch
# 1       567273_1_1        field_out    pitch
# 2       567273_1_2        field_out    pitch
# 3       567273_1_3        field_out    pitch
# 4       567273_1_4        field_out    pitch
# 5       567273_1_5        field_out    pitch
# 6       567273_2_6             walk    pitch
# 7       567273_2_7             walk    pitch
# 8       567273_2_8             walk   action
# 9       567273_2_9             walk    pitch
# 10     567273_2_10             walk    pitch
# 11     567273_2_11             walk    pitch
# 12     567273_2_12             walk    pitch
# 13     567273_2_13             walk    pitch
# 14     567273_3_14             walk    pitch
# 15     567273_3_15             walk    pitch
# 16     567273_3_16             walk    pitch
# 17     567273_3_17             walk  pickoff
# 18     567273_3_18             walk    pitch
# 19     567273_3_19             walk    pitch
# 20     567273_4_20     hit_by_pitch    pitch
# 21     567273_4_21     hit_by_pitch    pitch
# 22     567273_4_22     hit_by_pitch    pitch
# 23     567273_4_23     hit_by_pitch    pitch
# 24     567273_4_24     hit_by_pitch    pitch
# 25     567273_5_25           single   action
# 26     567273_5_26           single    pitch
# 27     567273_5_27           single    pitch
# 28     567273_6_28             walk    pitch
# 29     567273_6_29             walk    pitch
# ..             ...              ...      ...
# 170  567273_38_170        field_out    pitch
# 171  567273_39_171        field_out    pitch
# 172  567273_39_172        field_out    pitch
# 173  567273_39_173        field_out    pitch
# 174  567273_39_174        field_out    pitch
# 175  567273_39_175        field_out    pitch
# 176  567273_40_176        strikeout    pitch
# 177  567273_40_177        strikeout    pitch
# 178  567273_40_178        strikeout    pitch
# 179  567273_41_179         home_run    pitch
# 180  567273_42_180        strikeout    pitch
# 181  567273_42_181        strikeout    pitch
# 182  567273_42_182        strikeout    pitch
# 183  567273_42_183        strikeout    pitch
# 184  567273_42_184        strikeout    pitch
# 185  567273_43_185        field_out   action
# 186  567273_43_186        field_out   action
# 187  567273_43_187        field_out    pitch
# 188  567273_43_188        field_out    pitch
# 189  567273_43_189        field_out    pitch
# 190  567273_43_190        field_out    pitch
# 191  567273_43_191        field_out    pitch
# 192  567273_44_192        field_out   action
# 193  567273_44_193        field_out    pitch
# 194  567273_44_194        field_out    pitch
# 195  567273_44_195        field_out    pitch
# 196  567273_45_196        strikeout    pitch
# 197  567273_45_197        strikeout    pitch
# 198  567273_45_198        strikeout    pitch
# 199  567273_45_199        strikeout    pitch
#
# [200 rows x 28 columns]

# %% [markdown]
# ### NEXT STEPS:
# - Add a previous pitch column
# - Scrape June 2018 and Sept 2018 hitting and pitching data
# - Match the player stats to the name column in the pitch data
# - Modify men on base
# - Drop play result and type column

# %%
pitch_id_df = each_pitch[['pitch_id', 'details.type.code']].copy()
pitch_id_df.head()
# Out:
#      pitch_id details.type.code
# 0  567273_0_1                FF
# 1  567273_1_2                FF
# 2  567273_1_3                FF
# 3  567273_1_4                FF
# 4  567273_1_5                FF

# %%
merged_df = pd.merge(each_pitch, pitch_id_df,how='left', left_on='prior_pitch', right_on='pitch_id')

# %%
merged_df.head(2)
# Out:
#    about.atBatIndex about.halfInning  about.inning  count.balls  \
# 0                 0              top             1          0.0
# 1                 1              top             1          1.0
#
#    count.strikes       details.ballColor details.call.code  \
# 0            0.0  rgba(26, 86, 190, 1.0)                 X
# 1            0.0  rgba(39, 161, 39, 1.0)                 B
#
#   details.call.description details.code details.description  \
# 0   Hit Into Play - Out(s)            X     In play, out(s)
# 1            Ball - Called            B                Ball
#
#   details.type.code_x details.type.description  gamepk  index  \
# 0                  FF       Four-Seam Fastball  567273      0
# 1                  FF       Four-Seam Fastball  567273      0
#
#   matchup.batSide.code matchup.batter.fullName  matchup.batter.id  \
# 0                    R            JaCoby Jones             592444
# 1                    L        Christin Stewart             621514
#
#   matchup.pitchHand.code matchup.pitcher.fullName  matchup.pitcher.id  \
# 0                      R              Dylan Cease              656302
# 1                      R              Dylan Cease              656302
#
#   matchup.splits.menOnBase  pitchData.nastyFactor  pitchData.zone  \
# 0                    Empty                    NaN             NaN
# 1                    Empty                    NaN             NaN
#
#    pitchNumber  pitch_id_x prior_pitch result.eventType   type pitch_id_y  \
# 0          1.0  567273_0_1  567273_0_0        field_out  pitch        NaN
# 1          1.0  567273_1_2  567273_1_1        field_out  pitch        NaN
#
#   details.type.code_y
# 0                 NaN
# 1                 NaN

# %%
each_pitch_merged = merged_df

# %%
each_pitch_merged = each_pitch_merged.rename({'pitch_id_y': 'previous_pitch_in_ab', 'details.type.code_y': 'previous_pitch_code'}, axis=1)

# %%
each_pitch_merged.head(2)
# Out:
#    about.atBatIndex about.halfInning  about.inning  count.balls  \
# 0                 0              top             1          0.0
# 1                 1              top             1          1.0
#
#    count.strikes       details.ballColor details.call.code  \
# 0            0.0  rgba(26, 86, 190, 1.0)                 X
# 1            0.0  rgba(39, 161, 39, 1.0)                 B
#
#   details.call.description details.code details.description  \
# 0   Hit Into Play - Out(s)            X     In play, out(s)
# 1            Ball - Called            B                Ball
#
#   details.type.code_x details.type.description  gamepk  index  \
# 0                  FF       Four-Seam Fastball  567273      0
# 1                  FF       Four-Seam Fastball  567273      0
#
#   matchup.batSide.code matchup.batter.fullName  matchup.batter.id  \
# 0                    R            JaCoby Jones             592444
# 1                    L        Christin Stewart             621514
#
#   matchup.pitchHand.code matchup.pitcher.fullName  matchup.pitcher.id  \
# 0                      R              Dylan Cease              656302
# 1                      R              Dylan Cease              656302
#
#   matchup.splits.menOnBase  pitchData.nastyFactor  pitchData.zone  \
# 0                    Empty                    NaN             NaN
# 1                    Empty                    NaN             NaN
#
#    pitchNumber  pitch_id_x prior_pitch result.eventType   type  \
# 0          1.0  567273_0_1  567273_0_0        field_out  pitch
# 1          1.0  567273_1_2  567273_1_1        field_out  pitch
#
#   previous_pitch_in_ab previous_pitch_code
# 0                  NaN                 NaN
# 1                  NaN                 NaN

# %%
each_pitch_clean = each_pitch_merged.drop(['result.eventType', 'type', 'pitch_id_x', 'previous_pitch_in_ab', 'prior_pitch', 'details.ballColor'], axis=1)

# %%
each_pitch_clean.head(2)
# Out:
#    about.atBatIndex about.halfInning  about.inning  count.balls  \
# 0                 0              top             1          0.0
# 1                 1              top             1          1.0
#
#    count.strikes details.call.code details.call.description details.code  \
# 0            0.0                 X   Hit Into Play - Out(s)            X
# 1            0.0                 B            Ball - Called            B
#
#   details.description details.type.code_x details.type.description  gamepk  \
# 0     In play, out(s)                  FF       Four-Seam Fastball  567273
# 1                Ball                  FF       Four-Seam Fastball  567273
#
#    index matchup.batSide.code matchup.batter.fullName  matchup.batter.id  \
# 0      0                    R            JaCoby Jones             592444
# 1      0                    L        Christin Stewart             621514
#
#   matchup.pitchHand.code matchup.pitcher.fullName  matchup.pitcher.id  \
# 0                      R              Dylan Cease              656302
# 1                      R              Dylan Cease              656302
#
#   matchup.splits.menOnBase  pitchData.nastyFactor  pitchData.zone  \
# 0                    Empty                    NaN             NaN
# 1                    Empty                    NaN             NaN
#
#    pitchNumber previous_pitch_code
# 0          1.0                 NaN
# 1          1.0                 NaN

# %% [markdown]
# ## Pitch Modification
# There are three types of pitches(fastballs, breaking balls, and change-ups).
# Hitters really only need to know which one of these types will be coming next. I think by narrowing the options, it will help the model make better predictions.

# %%
pitch_dict = {'FF': 'Fastball'}

# %%
pitch_dict['FT'] = 'Fastball'
pitch_dict['FC']= 'Fastball'
pitch_dict['FS'] = 'Fastball'
pitch_dict['CH'] = 'Changeup'
pitch_dict['SI'] = 'Fastball'
pitch_dict['FT'] = 'Fastball'
pitch_dict['CU'] = 'Breaking_Ball'
pitch_dict['SL'] = 'Breaking_Ball'
pitch_dict['KC'] = 'Breaking_Ball'
pitch_dict['nan'] = 'NA'

# %%
each_pitch_clean['pitch_type'] = each_pitch_clean['details.type.code_x'].map(pitch_dict)

# %%
each_pitch_clean['prior_pitch_type'] = each_pitch_clean['previous_pitch_code'].map(pitch_dict)

# %%
each_pitch_clean = each_pitch_clean.drop(['details.type.code_x', 'details.type.description', 'details.code', 'gamepk', 'index', 'matchup.batter.id'],axis=1)

# %%
each_pitch_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 20 columns):
# about.atBatIndex            200 non-null int64
# about.halfInning            200 non-null object
# about.inning                200 non-null int64
# count.balls                 197 non-null float64
# count.strikes               197 non-null float64
# details.call.code           189 non-null object
# details.call.description    189 non-null object
# details.description         200 non-null object
# matchup.batSide.code        200 non-null object
# matchup.batter.fullName     200 non-null object
# matchup.pitchHand.code      200 non-null object
# matchup.pitcher.fullName    200 non-null object
# matchup.pitcher.id          200 non-null int64
# matchup.splits.menOnBase    200 non-null object
# pitchData.nastyFactor       0 non-null float64
# pitchData.zone              0 non-null float64
# pitchNumber                 189 non-null float64
# previous_pitch_code         143 non-null object
# pitch_type                  189 non-null object
# prior_pitch_type            143 non-null object
# dtypes: float64(5), int64(3), object(12)
# memory usage: 32.8+ KB

# %%
each_pitch_clean.to_csv(r'public_data/standard_pitch.csv', index=False, sep=',', encoding='utf-8')

# %%
each_pitch_clean.to_csv(r'public_data/tigers.csv', index=False, sep=',', encoding='utf-8')

# %% [markdown]
# ## Pipeline Preparation

# %%
pitch_clean = each_pitch_clean.dropna().copy()

# %%
# Lost about 600, but this is just a test
pitch_clean.head(2)
# Out:
#    about.atBatIndex about.halfInning  about.inning  count.balls  \
# 2                 1              top             1          2.0
# 3                 1              top             1          2.0
#
#    count.strikes details.call.code details.call.description  \
# 2            0.0                 B            Ball - Called
# 3            1.0                 S        Strike - Swinging
#
#   details.description matchup.batSide.code matchup.batter.fullName  \
# 2                Ball                    R             Kris Bryant
# 3     Swinging Strike                    R             Kris Bryant
#
#   matchup.pitchHand.code matchup.pitcher.fullName  matchup.pitcher.id  \
# 2                      R               Jose Urena              570632
# 3                      R               Jose Urena              570632
#
#   matchup.splits.menOnBase  pitchData.nastyFactor  pitchData.zone  \
# 2                   Men_On                  29.02            13.0
# 3                   Men_On                  41.63            13.0
#
#    pitchNumber previous_pitch_code pitch_type prior_pitch_type
# 2          2.0                  FT   Fastball         Fastball
# 3          3.0                  FT   Fastball         Fastball

# %%
target = pitch_clean['pitch_type']

# %%
predictors = pitch_clean.drop(['pitch_type', 'matchup.pitcher.fullName', 'matchup.batter.fullName'], axis=1)

# %%
numerical_values = list(predictors['pitchNumber'])

# %%
num_features = list(predictors.select_dtypes(exclude='object'))

# %%
numeric_transformer = Pipeline(steps=[('keeper', None)])

# %%
categorical_value_df = predictors.drop(['pitchNumber'], axis=1)

# %%
categorial_values = list(categorical_value_df)

# %%
cat_features = list(predictors.select_dtypes(include='object'))

# %%
cat_transfomer = Pipeline(steps=[('onehot', OneHotEncoder())])

# %%
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, num_features),
                                              ('cat', cat_transfomer, cat_features)])

# %%
classifiers = [DecisionTreeClassifier(), RandomForestClassifier(n_estimators=100, max_depth=5), 
               GradientBoostingClassifier(n_estimators=100), xgb.XGBClassifier()]

# %% [markdown]
# ## Model Creation

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, random_state=10)

# %%
#X_test[X_test['matchup.batter.fullName'].str.contains("Lucas Sims")==True]

# %%
for classifier in classifiers:
    #Intialize classifier pipeline
    clf1 = Pipeline(steps=[('preprocessor', preprocessor),
                          ('classifier', classifier)])
    clf1.fit(X_train, y_train)
    one_hot_names = list(clf1.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names())
    final_feats = num_features + one_hot_names
    # Print accuracy metrics for each model using pitch_functions.py
    print(classifier)
    print('\n')
    print('Training Metrics')
    pitch_functions.calc_acc_and_f1_score(y_train, clf1.predict(X_train))
    print('\n')
    print('Testing Metrics')
    pitch_functions.calc_acc_and_f1_score(y_test, clf1.predict(X_test))
    print('\n')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
#
#
# Training Metrics
# Accuracy:1.000
# F1-Score: 1.000
# AUC: 1.000
#
#
# Testing Metrics
# Accuracy:0.627
# F1-Score: 0.629
# AUC: 0.646
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
#
# Training Metrics
# Accuracy:0.648
# F1-Score: 0.547
# AUC: 0.544
#
#
# Testing Metrics
# Accuracy:0.652
# F1-Score: 0.552
# AUC: 0.544
#
#
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
#
#
# Training Metrics
# Accuracy:0.711
# F1-Score: 0.674
# AUC: 0.648
#
#
# Testing Metrics
# Accuracy:0.712
# F1-Score: 0.676
# AUC: 0.648
#
#
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='multi:softprob', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)
#
#
# Training Metrics
# Accuracy:0.699
# F1-Score: 0.655
# AUC: 0.629
#
#
# Testing Metrics
# Accuracy:0.701
# F1-Score: 0.658
# AUC: 0.630
