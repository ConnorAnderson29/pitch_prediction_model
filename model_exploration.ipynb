# %% [markdown]
# # Model Creation: Round 2 -USELESS DONT SCROLL ANYMORE

# %% [markdown]
# #### Importing the necessary libraries

# %%
import pitch_functions 
import library as lib
import pandas as pd
import os

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
each_pitch = pd.read_csv('raw_data/cleaned_pitches.csv')

# %% [markdown]
# ## Pipeline Preparation

# %%
pitch_clean = each_pitch.dropna().copy()

# %%
pitch_clean = pitch_clean[:100000]

# %%
pitch_clean
# Out:
#                pitcher  WAR_x  WHIP  ERA  SO           hitter    SLG    OPS  \
# 0      Kendrys Morales    0.0  1.00  0.0   0     Matt Chapman  0.508  0.864
# 1      Kendrys Morales    0.0  1.00  0.0   0     Matt Chapman  0.508  0.864
# 2      Kendrys Morales    0.0  1.00  0.0   0     Matt Chapman  0.508  0.864
# 3      Kendrys Morales    0.0  1.00  0.0   0     Matt Chapman  0.508  0.864
# 4      Kendrys Morales    0.0  1.00  0.0   0     Matt Chapman  0.508  0.864
# 5      Kendrys Morales    0.0  1.00  0.0   0       Matt Olson  0.453  0.788
# 6      Kendrys Morales    0.0  1.00  0.0   0       Matt Olson  0.453  0.788
# 7      Kendrys Morales    0.0  1.00  0.0   0       Matt Olson  0.453  0.788
# 8      Kendrys Morales    0.0  1.00  0.0   0       Matt Olson  0.453  0.788
# 9      Kendrys Morales    0.0  1.00  0.0   0  Jonathan Lucroy  0.325  0.617
# 10     Kendrys Morales    0.0  1.00  0.0   0  Jonathan Lucroy  0.325  0.617
# 11     Kendrys Morales    0.0  1.00  0.0   0  Jonathan Lucroy  0.325  0.617
# 12       Mark Reynolds    0.0  0.00  0.0   0    Bryan Holaday  0.258  0.519
# 13       Mark Reynolds    0.0  0.00  0.0   0    Bryan Holaday  0.258  0.519
# 14      Pablo Sandoval    0.0  0.00  0.0   0        Max Muncy  0.582  0.973
# 15      Pablo Sandoval    0.0  0.00  0.0   0     Chris Taylor  0.444  0.775
# 16      Pablo Sandoval    0.0  0.00  0.0   0     Chris Taylor  0.444  0.775
# 17      Pablo Sandoval    0.0  0.00  0.0   0     Chris Taylor  0.444  0.775
# 18      Pablo Sandoval    0.0  0.00  0.0   0  Yasmani Grandal  0.466  0.815
# 19      Pablo Sandoval    0.0  0.00  0.0   0  Yasmani Grandal  0.466  0.815
# 20      Pablo Sandoval    0.0  0.00  0.0   0  Yasmani Grandal  0.466  0.815
# 21      Pablo Sandoval    0.0  0.00  0.0   0  Yasmani Grandal  0.466  0.815
# 22      Danny Valencia    0.0  0.00  0.0   1       Joey Gallo  0.498  0.810
# 23      Danny Valencia    0.0  0.00  0.0   1       Joey Gallo  0.498  0.810
# 24      Danny Valencia    0.0  0.00  0.0   1       Joey Gallo  0.498  0.810
# 25      Danny Valencia    0.0  0.00  0.0   1       Joey Gallo  0.498  0.810
# 26      Danny Valencia    0.0  0.00  0.0   1       Joey Gallo  0.498  0.810
# 27      Danny Valencia    0.0  0.00  0.0   1       Joey Gallo  0.498  0.810
# 28          Alex Avila    0.1  0.50  0.0   0      Ian Desmond  0.422  0.729
# 29          Alex Avila    0.1  0.50  0.0   0      Noel Cuevas  0.315  0.583
# ...                ...    ...   ...  ...  ..              ...    ...    ...
# 99970     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99971     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99972     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99973     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99974     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99975     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99976     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99977     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99978     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99979     Zack Britton    0.7  1.23  3.1  34     Trey Mancini  0.416  0.715
# 99980     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99981     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99982     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99983     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99984     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99985     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99986     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99987     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99988     Zack Britton    0.7  1.23  3.1  34     Justin Smoak  0.457  0.808
# 99989     Zack Britton    0.7  1.23  3.1  34  Jonathan Lucroy  0.325  0.617
# 99990     Zack Britton    0.7  1.23  3.1  34  Jonathan Lucroy  0.325  0.617
# 99991     Zack Britton    0.7  1.23  3.1  34  Jonathan Lucroy  0.325  0.617
# 99992     Zack Britton    0.7  1.23  3.1  34      Ian Kinsler  0.380  0.681
# 99993     Zack Britton    0.7  1.23  3.1  34      Ian Kinsler  0.380  0.681
# 99994     Zack Britton    0.7  1.23  3.1  34      Ian Kinsler  0.380  0.681
# 99995     Zack Britton    0.7  1.23  3.1  34      Ian Kinsler  0.380  0.681
# 99996     Zack Britton    0.7  1.23  3.1  34      Ian Kinsler  0.380  0.681
# 99997     Zack Britton    0.7  1.23  3.1  34      Ian Kinsler  0.380  0.681
# 99998     Zack Britton    0.7  1.23  3.1  34    Rafael Devers  0.433  0.731
# 99999     Zack Britton    0.7  1.23  3.1  34    Rafael Devers  0.433  0.731
#
#        WAR_y  about.atBatIndex   ...    matchup.batSide.code  \
# 0        8.2                70   ...                       R
# 1        8.2                70   ...                       R
# 2        8.2                70   ...                       R
# 3        8.2                70   ...                       R
# 4        8.2                70   ...                       R
# 5        4.3                69   ...                       L
# 6        4.3                69   ...                       L
# 7        4.3                69   ...                       L
# 8        4.3                69   ...                       L
# 9       -0.7                72   ...                       R
# 10      -0.7                72   ...                       R
# 11      -0.7                72   ...                       R
# 12       0.1                90   ...                       R
# 13       0.1                90   ...                       R
# 14       4.2                90   ...                       L
# 15       4.1                92   ...                       R
# 16       4.1                92   ...                       R
# 17       4.1                92   ...                       R
# 18       3.3                91   ...                       L
# 19       3.3                91   ...                       L
# 20       3.3                91   ...                       L
# 21       3.3                91   ...                       L
# 22       2.1                87   ...                       L
# 23       2.1                87   ...                       L
# 24       2.1                87   ...                       L
# 25       2.1                87   ...                       L
# 26       2.1                87   ...                       L
# 27       2.1                87   ...                       L
# 28      -0.6                70   ...                       R
# 29      -1.5                72   ...                       R
# ...      ...               ...   ...                     ...
# 99970   -0.1                84   ...                       R
# 99971   -0.1                84   ...                       R
# 99972   -0.1                84   ...                       R
# 99973   -0.1                62   ...                       R
# 99974   -0.1                62   ...                       R
# 99975   -0.1                62   ...                       R
# 99976   -0.1                58   ...                       R
# 99977   -0.1                58   ...                       R
# 99978   -0.1                58   ...                       R
# 99979   -0.1                58   ...                       R
# 99980    2.3                59   ...                       R
# 99981    2.3                59   ...                       R
# 99982    2.3                59   ...                       R
# 99983    2.3                59   ...                       R
# 99984    2.3                59   ...                       R
# 99985    2.3                59   ...                       R
# 99986    2.3                59   ...                       R
# 99987    2.3                59   ...                       R
# 99988    2.3                59   ...                       R
# 99989   -0.7                58   ...                       R
# 99990   -0.7                58   ...                       R
# 99991   -0.7                58   ...                       R
# 99992    2.4                83   ...                       R
# 99993    2.4                83   ...                       R
# 99994    2.4                68   ...                       R
# 99995    2.4                79   ...                       R
# 99996    2.4                79   ...                       R
# 99997    2.4                79   ...                       R
# 99998   -0.0                59   ...                       L
# 99999   -0.0                59   ...                       L
#
#        matchup.pitchHand.code matchup.pitcher.id matchup.splits.menOnBase  \
# 0                           R             434778                   Men_On
# 1                           R             434778                   Men_On
# 2                           R             434778                   Men_On
# 3                           R             434778                   Men_On
# 4                           R             434778                   Men_On
# 5                           R             434778                    Empty
# 6                           R             434778                    Empty
# 7                           R             434778                    Empty
# 8                           R             434778                    Empty
# 9                           R             434778                    Empty
# 10                          R             434778                    Empty
# 11                          R             434778                    Empty
# 12                          R             448602                    Empty
# 13                          R             448602                    Empty
# 14                          R             467055                    Empty
# 15                          R             467055                    Empty
# 16                          R             467055                    Empty
# 17                          R             467055                    Empty
# 18                          R             467055                    Empty
# 19                          R             467055                    Empty
# 20                          R             467055                    Empty
# 21                          R             467055                    Empty
# 22                          R             502143                    Empty
# 23                          R             502143                    Empty
# 24                          R             502143                    Empty
# 25                          R             502143                    Empty
# 26                          R             502143                    Empty
# 27                          R             502143                    Empty
# 28                          R             488671                   Men_On
# 29                          R             488671                   Men_On
# ...                       ...                ...                      ...
# 99970                       L             502154                    Empty
# 99971                       L             502154                    Empty
# 99972                       L             502154                    Empty
# 99973                       L             502154                     RISP
# 99974                       L             502154                     RISP
# 99975                       L             502154                     RISP
# 99976                       L             502154                    Empty
# 99977                       L             502154                    Empty
# 99978                       L             502154                    Empty
# 99979                       L             502154                    Empty
# 99980                       L             502154                   Men_On
# 99981                       L             502154                   Men_On
# 99982                       L             502154                   Men_On
# 99983                       L             502154                   Men_On
# 99984                       L             502154                   Men_On
# 99985                       L             502154                   Men_On
# 99986                       L             502154                   Men_On
# 99987                       L             502154                   Men_On
# 99988                       L             502154                   Men_On
# 99989                       L             502154                    Empty
# 99990                       L             502154                    Empty
# 99991                       L             502154                    Empty
# 99992                       L             502154                    Empty
# 99993                       L             502154                    Empty
# 99994                       L             502154                     RISP
# 99995                       L             502154                   Men_On
# 99996                       L             502154                   Men_On
# 99997                       L             502154                   Men_On
# 99998                       L             502154                   Men_On
# 99999                       L             502154                   Men_On
#
#       pitchData.nastyFactor pitchData.zone  pitchNumber     pitch_type  \
# 0                     32.94            1.0          2.0       Changeup
# 1                     31.44            4.0          3.0  Breaking_Ball
# 2                      2.66           14.0          4.0  Breaking_Ball
# 3                      3.82           14.0          5.0  Breaking_Ball
# 4                     35.64           11.0          6.0  Breaking_Ball
# 5                     10.87           11.0          2.0       Changeup
# 6                     14.74           11.0          3.0       Changeup
# 7                     31.15            4.0          4.0       Changeup
# 8                     42.48            7.0          5.0       Changeup
# 9                     42.92           13.0          2.0  Breaking_Ball
# 10                    35.29           11.0          3.0  Breaking_Ball
# 11                    22.37            2.0          4.0       Changeup
# 12                    12.91           12.0          2.0  Breaking_Ball
# 13                    36.44           14.0          3.0  Breaking_Ball
# 14                    26.07            4.0          2.0       Changeup
# 15                    31.48            9.0          2.0  Breaking_Ball
# 16                    35.89            1.0          3.0  Breaking_Ball
# 17                    20.72            6.0          4.0       Changeup
# 18                    21.19           13.0          2.0  Breaking_Ball
# 19                    14.87           11.0          3.0  Breaking_Ball
# 20                    38.46            7.0          4.0       Changeup
# 21                    59.34           13.0          5.0       Changeup
# 22                    19.56           11.0          2.0       Fastball
# 23                    29.92           14.0          3.0  Breaking_Ball
# 24                    42.10           12.0          4.0       Changeup
# 25                    69.21           11.0          5.0       Fastball
# 26                    47.72            3.0          6.0       Fastball
# 27                    66.01           11.0          7.0       Fastball
# 28                    33.85           11.0          2.0  Breaking_Ball
# 29                    13.00           13.0          2.0  Breaking_Ball
# ...                     ...            ...          ...            ...
# 99970                 48.90           13.0          3.0       Fastball
# 99971                 27.07           13.0          4.0       Fastball
# 99972                 48.11            7.0          5.0       Fastball
# 99973                 66.68           14.0          2.0       Fastball
# 99974                 23.11           13.0          4.0       Fastball
# 99975                 59.27           14.0          6.0       Fastball
# 99976                 23.11           14.0          2.0       Fastball
# 99977                 63.55           14.0          3.0       Fastball
# 99978                 23.58           13.0          4.0       Fastball
# 99979                 44.84           14.0          5.0       Fastball
# 99980                 41.83           13.0          2.0       Fastball
# 99981                 49.52           13.0          3.0       Fastball
# 99982                 25.09           13.0          4.0       Fastball
# 99983                 51.35            7.0          5.0       Fastball
# 99984                 39.32            6.0          6.0       Fastball
# 99985                 43.04           13.0          7.0       Fastball
# 99986                 11.11           13.0          2.0  Breaking_Ball
# 99987                 64.98           12.0          3.0       Fastball
# 99988                 31.32            8.0          4.0       Fastball
# 99989                 38.27           14.0          2.0       Fastball
# 99990                 39.16           12.0          3.0       Fastball
# 99991                 37.88            9.0          4.0       Fastball
# 99992                 51.29           13.0          2.0       Fastball
# 99993                 27.10            2.0          3.0       Fastball
# 99994                 58.07           14.0          2.0       Fastball
# 99995                 56.27           14.0          2.0       Fastball
# 99996                 26.96           12.0          3.0       Fastball
# 99997                 36.22           14.0          4.0       Fastball
# 99998                 34.64            6.0          2.0       Fastball
# 99999                 48.54           13.0          3.0       Fastball
#
#        prior_pitch_type    count
# 0              Changeup  1.0-1.0
# 1              Changeup  1.0-2.0
# 2         Breaking_Ball  2.0-2.0
# 3         Breaking_Ball  3.0-2.0
# 4         Breaking_Ball  4.0-2.0
# 5         Breaking_Ball  2.0-0.0
# 6              Changeup  3.0-0.0
# 7              Changeup  3.0-1.0
# 8              Changeup  3.0-1.0
# 9              Changeup  1.0-1.0
# 10        Breaking_Ball  2.0-1.0
# 11        Breaking_Ball  2.0-1.0
# 12        Breaking_Ball  2.0-0.0
# 13        Breaking_Ball  2.0-0.0
# 14             Changeup  1.0-0.0
# 15             Changeup  0.0-2.0
# 16        Breaking_Ball  0.0-2.0
# 17        Breaking_Ball  0.0-2.0
# 18        Breaking_Ball  1.0-1.0
# 19        Breaking_Ball  2.0-1.0
# 20        Breaking_Ball  2.0-2.0
# 21             Changeup  2.0-2.0
# 22        Breaking_Ball  1.0-1.0
# 23             Fastball  2.0-1.0
# 24        Breaking_Ball  2.0-2.0
# 25             Changeup  3.0-2.0
# 26             Fastball  3.0-2.0
# 27             Fastball  3.0-3.0
# 28        Breaking_Ball  1.0-0.0
# 29        Breaking_Ball  1.0-1.0
# ...                 ...      ...
# 99970          Fastball  1.0-2.0
# 99971          Fastball  2.0-2.0
# 99972          Fastball  2.0-2.0
# 99973          Fastball  2.0-0.0
# 99974          Fastball  3.0-1.0
# 99975          Fastball  3.0-3.0
# 99976          Fastball  1.0-1.0
# 99977          Fastball  1.0-2.0
# 99978          Fastball  2.0-2.0
# 99979          Fastball  2.0-2.0
# 99980          Fastball  2.0-0.0
# 99981          Fastball  2.0-1.0
# 99982          Fastball  3.0-1.0
# 99983          Fastball  3.0-2.0
# 99984          Fastball  3.0-2.0
# 99985          Fastball  4.0-2.0
# 99986          Fastball  1.0-1.0
# 99987     Breaking_Ball  2.0-1.0
# 99988          Fastball  2.0-1.0
# 99989          Fastball  1.0-1.0
# 99990          Fastball  2.0-1.0
# 99991          Fastball  2.0-1.0
# 99992          Fastball  1.0-1.0
# 99993          Fastball  1.0-1.0
# 99994          Fastball  1.0-0.0
# 99995          Fastball  2.0-0.0
# 99996          Fastball  3.0-0.0
# 99997          Fastball  4.0-0.0
# 99998          Fastball  0.0-2.0
# 99999          Fastball  1.0-2.0
#
# [100000 rows x 24 columns]

# %%
target = pitch_clean['pitch_type']

# %%
predictors = pitch_clean.drop(['pitch_type', 'hitter', 'pitcher'], axis=1)

# %%
num_features = list(predictors.select_dtypes(exclude='object'))

# %%
num_features
# Out:
# ['WAR_x',
#  'WHIP',
#  'ERA',
#  'SO',
#  'SLG',
#  'OPS',
#  'WAR_y',
#  'about.atBatIndex',
#  'about.inning',
#  'matchup.pitcher.id',
#  'pitchData.nastyFactor',
#  'pitchData.zone',
#  'pitchNumber']

# %%
num_features = [i for i in num_features if i not in {'about.inning', 'pitchData.zone'}]

# %%
num_features
# Out:
# ['WAR_x',
#  'WHIP',
#  'ERA',
#  'SO',
#  'SLG',
#  'OPS',
#  'WAR_y',
#  'about.atBatIndex',
#  'matchup.pitcher.id',
#  'pitchData.nastyFactor',
#  'pitchNumber']

# %%
numeric_transformer = lib.Pipeline(steps=[('keeper', None)])

# %%
cat_features = list(predictors.select_dtypes(include='object'))
cat_features.extend(['about.inning', 'pitchData.zone', 'count'])

# %%
cat_transfomer = lib.Pipeline(steps=[('onehot', lib.OneHotEncoder(handle_unknown='ignore', categories='auto'))])

# %%
preprocessor = lib.ColumnTransformer(transformers=[('num', numeric_transformer, num_features),
                                              ('cat', cat_transfomer, cat_features)])

# %%
classifiers = [lib.DecisionTreeClassifier(), lib.RandomForestClassifier(n_estimators=100, max_depth=5), 
               lib.GradientBoostingClassifier(n_estimators=100), lib.xgb.XGBClassifier()]

# %% [markdown]
# ## Model Creation

# %%
X_train, X_test, y_train, y_test = lib.train_test_split(predictors, target, random_state=10)

# %%
def run_classifier_models(classifiers, X_train, X_test, y_train, y_test):
    for classifier in classifiers:
        #Intialize classifier pipeline
        clf1 = lib.Pipeline(steps=[('preprocessor', preprocessor),
                              ('classifier', classifier)])
        clf1.fit(X_train, y_train)

        # Print accuracy metrics for each model using pitch_functions.py
        print(classifier)
        print('\n')
        print('Training Metrics')
        pitch_functions.calc_acc_and_f1_score(y_train, clf1.predict(X_train))
        print('\n')
        print('Testing Metrics')
        pitch_functions.calc_acc_and_f1_score(y_test, clf1.predict(X_test))
        print('\n')

# %% [markdown]
# - Need to get back to the drawing board
# - lets try dividing this up a little bit
# - national league teams
# - american league teams
# - start with the houston astros

# %%
run_classifier_models(classifiers, X_train, X_test, y_train, y_test)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
#
#
# Training Metrics
# Accuracy:1.000
# F1-Score: 1.000
# AUC: 1.000
#
#
# Testing Metrics
# Accuracy:0.669
# F1-Score: 0.670
# AUC: 0.678
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
#
# Training Metrics
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy:0.656
# F1-Score: 0.564
# AUC: 0.551
#
#
# Testing Metrics
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy:0.654
# F1-Score: 0.562
# AUC: 0.552
#
#
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
#
#
# Training Metrics
# Accuracy:0.736
# F1-Score: 0.711
# AUC: 0.674
#
#
# Testing Metrics
# Accuracy:0.732
# F1-Score: 0.707
# AUC: 0.671
#
#
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='multi:softprob', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
#
#
# Training Metrics
# Accuracy:0.719
# F1-Score: 0.684
# AUC: 0.644
#
#
# Testing Metrics
# Accuracy:0.719
# F1-Score: 0.682
# AUC: 0.644
